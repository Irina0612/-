# %% [markdown]
# ###  Научно-исследовательская работа
# ##### на тему: «Влияние пандемии COVID-19 на внутренний туризм России. Способствующие и препятствующие факторы развития»
#
# **Текст работы:**
# https://drive.google.com/drive/folders/1Ab2GR8oCmaR8hG3q7KRmXPxrtanalgyz?usp=sharing
#
# **Задание:**
# Анализ внутреннего туризма России 2020 года и выявление факторов, препятствующих его развитию.
#
# **Инструменты:**
# * Сводные таблицы Excel
# * Диаграммы Excel
# * Инструмент анализа: корреляция
#
#  Для работы использовались открыте данные Росстата, СберИндекса и Яндекса
#
# **Результат:**
# * Проанализирован туристический рынок России в 2020 году
# * Выполнен обзор мер государственной поддержки, оценка их своевременности и эффективности
# * Изучены наиболее популярные направления у туристов
# * Сделаны выводы какие факторы являются сдерживающими, над чем нужно работать в первую очередь
# * Даны практические рекомендации
